# %% [markdown]
# # Table 1: Baseline Characteristics

# %%
import pandas as pd
from eda_toolkit import generate_table1

# %%
df = pd.read_excel("../data/raw/kidney_uae.xlsx")

# %%
df = df.drop(columns=["time(months)"])

# %%
table1_cols_to_drop = ["Mean", "SD", "Median", "Min", "Max", "Mode", "Missing (n)", "Missing (%)"]

# %%
df_table1 = generate_table1(df=df, groupby_col="outcome", apply_bonferroni=True,  
                            value_counts=True,).drop(columns=table1_cols_to_drop)

# %%
df_table1
